# %% [markdown]
# # Proceso de Carga
#
# ## Módulo: Inteligencia de Negocios
#
# **Integrantes:**
# - Cristian González
# - Oscar Amagua
# - Rafael Espinosa
#
# ## Grupo
# Nro. 4
#
# ### Descripción del proyecto
#
#
# Este proyecto analiza datos de COVID-19 en México con el objetivo de construir un modelo dimensional en esquema estrella (Star Schema).
#
# En este notebook se documenta la etapa de **Carga (Load)** dentro del proceso ETL, en la cual los datos previamente procesados son trasladados hacia un entorno de análisis en la nube.
#
# Durante esta etapa, se exportan la tabla de hechos y las dimensiones en archivos CSV, para posteriormente ser cargados en Amazon S3 y transferidos a Redshift mediante sentencias SQL. Esto permite disponer del modelo estrella en una base de datos analítica, facilitando la ejecución de consultas y el análisis de la información.

# %% [markdown]
# # Configuración AWS

# %% [markdown]
# ## Configuración de Amazon Redshift Sin Servidor

# %% [markdown]
# En esta sección se muestra la configuración de Amazon Redshift en modo sin servidor, donde se observa que el entorno ya está disponible y listo para su uso.
#
# Este paso permite preparar la base de datos en la nube donde se cargarán y analizarán los datos del modelo estrella.

# %% [markdown]
# ![image.png](attachment:c658afe8-226f-44dc-bc24-c794f8c66ab5.png)

# %% [markdown]
# ### Grupo de trabajo

# %% [markdown]
# En esta sección se muestra el grupo de trabajo configurado en Amazon Redshift, donde se observan los detalles de conexión y el estado disponible del entorno.
#
# Esta configuración permite establecer la comunicación con el clúster de Redshift, facilitando la ejecución de consultas y el acceso a los datos cargados del modelo estrella.

# %% [markdown]
# ![image.png](attachment:c9b3041e-340d-482b-b73c-5d6fb54a788d.png)

# %% [markdown]
# ### Regla creada en el grupo de seguridad de la VPC

# %% [markdown]
# En esta sección se muestra la regla creada en el grupo de seguridad de la VPC, la cual permite el acceso al servicio de Redshift mediante el protocolo TCP en el puerto correspondiente.
#
# Esta configuración es necesaria para habilitar la conexión entre el entorno local y la base de datos en la nube, permitiendo ejecutar consultas y trabajar con los datos cargados del modelo estrella.

# %% [markdown]
# ![image.png](attachment:5ef8691c-65bb-4e34-869b-bc10c93bc39f.png)

# %% [markdown]
# ## Configuración del Amazon S3

# %% [markdown]
# ## S3 creado en AWS

# %% [markdown]
# En esta sección se muestra la creación de los buckets en Amazon S3, los cuales serán utilizados para almacenar los archivos generados del modelo estrella.
#
# Estos buckets permiten centralizar los datos en la nube y facilitan su posterior transferencia hacia Redshift para su análisis.

# %% [markdown]
# ![image.png](attachment:cfc8b245-9a1e-436e-be40-20f3154755b4.png)

# %% [markdown]
# ## Configuración de entorno analítico (Editor RedShift)
#
# En esta sección validamos la ejecución de consultas en el clúster de Redshift, evidenciando que la
# carga del modelo estrella se ha realizado correctamente.
# Mediante una consulta que integra la tabla de hechos con las dimensiones, se visualizan los datos
# completos de cada caso de COVID, incluyendo información como sexo, tipo de paciente, resultado
# y entidad.
#
# El resultado obtenido confirma que los datos han sido cargados y estructurados adecuadamente,
# permitiendo su análisis dentro del entorno analítico en la nube.

# %% [markdown]
# ![image.png](attachment:4e11782c-f77d-4185-9cc4-7079a5b7855c.png)
